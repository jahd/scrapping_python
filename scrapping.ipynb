# %%
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd

# %%
url="https://www.boulanger.com/c/refrigerateur?numPage=0"
response = requests.get(url)

# %%
html = response.content

# %%
soup = bs(html, "lxml")

# %%
articles = soup.find_all("article", class_="col-24 product-item")

# %%
article_informations = []
for article in articles:
    article_list = []
    name = article.find_all("h2", class_="product-item__label")[0].text
    price = article.find_all("p", class_="price__amount")[0].string
    keypoints = article.find_all("ul", class_="keypoints")[0].contents
    
    
    price = price.replace("\n", " ").replace(" ", "")
    name = name.replace("\n", "").strip()
    
    article_list.append(name)
    article_list.append(price)
    
    for keypoint in keypoints:
        my_content = keypoint.text.replace("\n", "").strip()
        if len(my_content) > 0:
            article_list.append(my_content)
            
    article_informations.append(article_list)

# %%
df = pd.DataFrame(article_informations, columns = ['product_name', 'price', 'dimensions', 'decibels_energy','volume','size',"+"])

# %%
df.head(8)
# Out:
#                                         product_name     price  \
# 0  Réfrigérateur combiné                  SAMSUNG...   679,00€
# 1  Réfrigérateur combiné                  INDESIT...   549,00€
# 2  Réfrigérateur Américain                  ESSEN...   699,00€
# 3  Réfrigérateur multi portes                  SA...  1299,00€
# 4  Réfrigérateur combiné encastrable             ...   749,00€
# 5  Réfrigérateur combiné                  LG     ...   949,00€
# 6  Réfrigérateur Américain                  SAMSU...  1699,00€
# 7  Réfrigérateur 2 portes                  LISTO ...   279,00€
#
#                        dimensions  \
# 0  LxHxP : 59.5 x 185.3 x 65.8 cm
# 1  LxHxP : 59.5 x 201.3 x 65.5 cm
# 2        LxHxP : 90 x 177 x 59 cm
# 3    LxHxP : 81.7 x 178 x 71.5 cm
# 4  LxHxP : 54.6 x 177.2 x 54.9 cm
# 5    LxHxP : 59.5 x 203 x 68.2 cm
# 6    LxHxP : 91.2 x 178 x 71.6 cm
# 7        LxHxP : 54 x 143 x 55 cm
#
#                                      decibels_energy  \
# 0  Silencieux (35dB) -                           ...
# 1  Silencieux (39dB) -                           ...
# 2  Niveau sonore de 40dB -                       ...
# 3  Niveau sonore de 40dB -                       ...
# 4  Silencieux (35dB) -                           ...
# 5  Silencieux (35dB) -                           ...
# 6  Silencieux (36dB) -                           ...
# 7  Niveau sonore de 41dB -                       ...
#
#                                               volume  \
# 0  Volume total : 344 L -                        ...
# 1  Volume total : 372 L -                        ...
# 2  Volume total : 442 L -                        ...
# 3  Volume total : 495 L -                        ...
# 4  Volume total : 269 L -                        ...
# 5  Volume total : 384 L -                        ...
# 6  Volume total : 634 L -                        ...
# 7  Volume total : 211 L -                        ...
#
#                                                 size  \
# 0  Frigo de : 230 L (idéal pour 2 personnes) -   ...
# 1  Frigo de : 261 L (idéal pour 3 personnes) -   ...
# 2  Frigo de : 291 L (idéal pour 3 personnes) -   ...
# 3  Frigo de : 330 L (idéal pour 4 personnes et +)...
# 4  Frigo de : 196 L (idéal pour 2 personnes) -   ...
# 5  Frigo de : 277 L (idéal pour 3 personnes) -   ...
# 6  Frigo de : 409 L (idéal pour 4 personnes et +)...
# 7  Frigo de : 170 L (idéal pour 2 personnes) -   ...
#
#                                                    +
# 0  Le + : Son faible niveau sonore (35 dB) et son...
# 1  Le + : Un intérieur aménagé pour faciliter le ...
# 2  Le + : Son écran tactile et balconnet XXL pour...
# 3  Le + : Son design minimaliste et ses portes pl...
# 4  Le + : Un refroidissement 40 % plus rapide grâ...
# 5  Le + : Son niveau sonore de 35 dB ultra silenc...
# 6  Le + : La technologie Space Max pour une grand...
# 7  Le + : Son excellent rapport volume utile / di...

# %%
# with first 10 pages : 
article_informations=[]

for i in range(1,10):
    url=f'https://www.boulanger.com/c/refrigerateur?numPage={i}'
    response = requests.get(url)
    html = response.content
    soup = bs(html, "lxml")
    
    articles = soup.find_all("article", class_="col-24 product-item")
    
    for article in articles:
        article_list = []
        name = article.find_all("h2", class_="product-item__label")[0].text
        price = article.find_all("p", class_="price__amount")[0].string
        keypoints = article.find_all("ul", class_="keypoints")[0].contents

        price = price.replace("\n", " ").replace(" ", "")
        name = name.replace("\n", "").strip()

        article_list.append(name)
        article_list.append(price)

        for keypoint in keypoints:
            my_content = keypoint.text.replace("\n", "").strip()
            if len(my_content) > 0:
                article_list.append(my_content)
        article_informations.append(article_list)
df = pd.DataFrame(article_informations, columns = ['product_name', 'price', 'dimensions', 'decibels_energy','volume','size',"+"])

# %%
df
# Out:
#                                           product_name     price  \
# 0    Réfrigérateur combiné                  SAMSUNG...   679,00€
# 1    Réfrigérateur combiné                  INDESIT...   549,00€
# 2    Réfrigérateur Américain                  ESSEN...   699,00€
# 3    Réfrigérateur multi portes                  SA...  1299,00€
# 4    Réfrigérateur combiné encastrable             ...   749,00€
# ..                                                 ...       ...
# 265  Réfrigérateur 1 porte encastrable             ...   599,00€
# 266  Réfrigérateur 1 porte encastrable             ...   886,99€
# 267  Réfrigérateur top                  LIEBHERR   ...   549,00€
# 268  Réfrigérateur 1 porte                  SMEG   ...  1399,00€
# 269  Réfrigérateur 1 porte encastrable             ...   799,00€
#
#                          dimensions  \
# 0    LxHxP : 59.5 x 185.3 x 65.8 cm
# 1    LxHxP : 59.5 x 201.3 x 65.5 cm
# 2          LxHxP : 90 x 177 x 59 cm
# 3      LxHxP : 81.7 x 178 x 71.5 cm
# 4    LxHxP : 54.6 x 177.2 x 54.9 cm
# ..                              ...
# 265   LxHxP : 54.8 x 87.3 x 54.9 cm
# 266  LxHxP : 55.9 x 121.8 x 54.6 cm
# 267     LxHxP : 55.4 x 63 x 62.4 cm
# 268      LxHxP : 60 x 153 x 72.8 cm
# 269     LxHxP : 59.6 x 81.5 x 55 cm
#
#                                        decibels_energy  \
# 0    Silencieux (35dB) -                           ...
# 1    Silencieux (39dB) -                           ...
# 2    Niveau sonore de 40dB -                       ...
# 3    Niveau sonore de 40dB -                       ...
# 4    Silencieux (35dB) -                           ...
# ..                                                 ...
# 265  Silencieux (37dB) -                           ...
# 266  Silencieux (35dB) -                           ...
# 267  Silencieux (37dB) -                           ...
# 268  Silencieux (35dB) -                           ...
# 269  Silencieux (38dB) -                           ...
#
#                                                 volume  \
# 0    Volume total : 344 L -                        ...
# 1    Volume total : 372 L -                        ...
# 2    Volume total : 442 L -                        ...
# 3    Volume total : 495 L -                        ...
# 4    Volume total : 269 L -                        ...
# ..                                                 ...
# 265  Volume total : 124 L -                        ...
# 266                               Volume total : 202 L
# 267                                Volume total : 98 L
# 268  Volume total : 270 L -                        ...
# 269  Volume total : 110 L -                        ...
#
#                                                   size  \
# 0    Frigo de : 230 L (idéal pour 2 personnes) -   ...
# 1    Frigo de : 261 L (idéal pour 3 personnes) -   ...
# 2    Frigo de : 291 L (idéal pour 3 personnes) -   ...
# 3    Frigo de : 330 L (idéal pour 4 personnes et +)...
# 4    Frigo de : 196 L (idéal pour 2 personnes) -   ...
# ..                                                 ...
# 265  Frigo de : 110 L (idéal pour 1 personne) -    ...
# 266          Frigo de : 202 L (idéal pour 2 personnes)
# 267  Frigo de : 92 L (idéal pour 1 personne) -     ...
# 268  Frigo de : 244 L (idéal pour 2 personnes) -   ...
# 269  Frigo de : 94 L (idéal pour 1 personne) -     ...
#
#                                                      +
# 0    Le + : Son faible niveau sonore (35 dB) et son...
# 1    Le + : Un intérieur aménagé pour faciliter le ...
# 2    Le + : Son écran tactile et balconnet XXL pour...
# 3    Le + : Son design minimaliste et ses portes pl...
# 4    Le + : Un refroidissement 40 % plus rapide grâ...
# ..                                                 ...
# 265            Le + : son design pratique et efficace.
# 266  Le + : Spacieux, le tiroir EasyFresh assure de...
# 267          Le + : Son silence et son mini freezer 6L
# 268  Le + : Collection vintage et rétro des années 50'
# 269  Le + : Une congélation efficace intégrée au ré...
#
# [270 rows x 7 columns]
